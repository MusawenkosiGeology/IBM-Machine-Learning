# %% [markdown]
# ## Project 1 - Exploratory Data Analysis for Machine Learning

# %% [markdown]
# Data source: Board Games - Tidy Tuesday

# %% [markdown]
# # 1. Data Overview

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

#%config InlineBackend.figure_formats = ['retina']

# %%
# Load in the dataset
data = pd.read_csv(r'C:\Users\698422\Desktop\Courses\Data Science\Machine Learning\board_games.csv')

# %%
# Create train set and test set
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=0.2, random_state=0)

# %%
# First look
train.head()
# Out:
#       game_id                                        description  \
# 6168    41933  In the year 2097, the entire Earth was envelop...
# 9652   173090  Players in The Game try to discard all 98 card...
# 5007    25224  In a distant land, many and many years ago, ro...
# 7409   103843  Game description from the publisher:&#10;&#10;...
# 3030     6946  Strategy &amp; Tactics magazine #47.&#10;&#10;...
#
#                                              image  max_players  max_playtime  \
# 6168  //cf.geekdo-images.com/images/pic1114682.jpg            5            60
# 9652  //cf.geekdo-images.com/images/pic2405167.jpg            5            20
# 5007   //cf.geekdo-images.com/images/pic143036.jpg            5           120
# 7409  //cf.geekdo-images.com/images/pic1054173.jpg            6            30
# 3030  //cf.geekdo-images.com/images/pic2666458.jpg            1           120
#
#       min_age  min_players  min_playtime               name  playing_time  \
# 6168       12            2            45  Arctic Scavengers            60
# 9652        8            1            20           The Game            20
# 5007       12            2            90           Hermagor           120
# 7409        8            2            30          Fandooble            30
# 3030       12            1           120           Wolfpack           120
#
#       ...                                   artist  \
# 6168  ...              Matt Burton,Martin Hoffmann
# 9652  ...  Oliver Freudenreich,Sandra Freudenreich
# 5007  ...                                   Czarnè
# 7409  ...                              Fian Arroyo
# 3030  ...                      Redmond A. Simonsen
#
#                               category                            compilation  \
# 6168       Bluffing,Card Game,Fighting  Arctic Scavengers: Base Game+HQ+Recon
# 9652                  Card Game,Number         The Game on Fire (compilation)
# 5007  Economic,Medieval,Transportation                                    NaN
# 7409                           Fantasy                                    NaN
# 3030     Nautical,Wargame,World War II                                    NaN
#
#                designer                                       expansion  \
# 6168  Robert K. Gabhart  Arctic Scavengers: HQ,Arctic Scavengers: Recon
# 9652   Steffen Benndorf                    The Game on Fire (expansion)
# 5007   Emanuele Ornella                                             NaN
# 7409        Mike Richie                                             NaN
# 3030       Jim Dunnigan                                             NaN
#
#                                                  family  \
# 6168                     Arctic Scavengers,Arctic Theme
# 9652                                    Solitaire Games
# 5007                                                NaN
# 7409                                   Animals: Dragons
# 3030  Magazine: Strategy & Tactics,Solitaire Games,S...
#
#                                                mechanic  \
# 6168  Card Drafting,Deck / Pool Building,Hand Manage...
# 9652                  Co-operative Play,Hand Management
# 5007  Area Control / Area Influence,Auction/Bidding,...
# 7409                       Dice Rolling,Press Your Luck
# 3030                       Dice Rolling,Hex-and-Counter
#
#                                               publisher average_rating  \
# 6168      Driftwood Games,Rio Grande Games,Ystari Games        6.97479
# 9652  Nürnberger-Spielkarten-Verlag,dV Giochi,Game F...        6.75647
# 5007  Mind the Move,Quined White Goblin Games,Rio Gr...        6.92051
# 7409                                    Mindtwister USA        6.09375
# 3030               SPI (Simulations Publications, Inc.)        6.05192
#
#      users_rated
# 6168        2182
# 9652        3480
# 5007        1643
# 7409          80
# 3030         156
#
# [5 rows x 22 columns]

# %%
# Examine columns
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8425 entries, 6168 to 2732
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   game_id         8425 non-null   int64
#  1   description     8425 non-null   object
#  2   image           8424 non-null   object
#  3   max_players     8425 non-null   int64
#  4   max_playtime    8425 non-null   int64
#  5   min_age         8425 non-null   int64
#  6   min_players     8425 non-null   int64
#  7   min_playtime    8425 non-null   int64
#  8   name            8425 non-null   object
#  9   playing_time    8425 non-null   int64
#  10  thumbnail       8424 non-null   object
#  11  year_published  8425 non-null   int64
#  12  artist          6187 non-null   object
#  13  category        8346 non-null   object
#  14  compilation     322 non-null    object
#  15  designer        8331 non-null   object
#  16  expansion       2189 non-null   object
#  17  family          6170 non-null   object
#  18  mechanic        7674 non-null   object
#  19  publisher       8423 non-null   object
#  20  average_rating  8425 non-null   float64
#  21  users_rated     8425 non-null   int64
# dtypes: float64(1), int64(9), object(12)
# memory usage: 1.5+ MB

# %%
# Examine missing data
train.isnull().sum().sort_values()
# Out:
# game_id              0
# year_published       0
# average_rating       0
# playing_time         0
# name                 0
# min_playtime         0
# users_rated          0
# min_age              0
# max_playtime         0
# max_players          0
# description          0
# min_players          0
# image                1
# thumbnail            1
# publisher            2
# category            79
# designer            94
# mechanic           751
# artist            2238
# family            2255
# expansion         6236
# compilation       8103
# dtype: int64

# %% [markdown]
# ## 2. Data Cleaning and Feature Engineering: Categorical Data

# %%
# Have a look at all categorical variables
train.describe(include='object').T
# Out:
#             count unique                                                top  \
# description  8425   8423  Hoplomachus [ha-ploh-ma-kuss], or &quot;Hoplo&...
# image        8424   8422       //cf.geekdo-images.com/images/pic2262580.png
# name         8425   8314                                         Robin Hood
# thumbnail    8424   8422     //cf.geekdo-images.com/images/pic2262580_t.png
# artist       6187   3881                                    Franz Vohwinkel
# category     8346   3310                               Wargame,World War II
# compilation   322    269                                     Pyramid Arcade
# designer     8331   3978                                       (Uncredited)
# expansion    2189   2106  Règlement de l'An XXX,Regulations of the Year ...
# family       6170   3321                          Crowdfunding: Kickstarter
# mechanic     7674   2708                                    Hex-and-Counter
# publisher    8423   4538                                          GMT Games
#
#             freq
# description    2
# image          2
# name           5
# thumbnail      2
# artist       141
# category     364
# compilation    6
# designer     442
# expansion      7
# family       312
# mechanic     406
# publisher    140

# %%
# Keep original data
df = train.copy()

# %%
# Remove features that have too many missing values or those that can't help discriminate the target
df.drop(['game_id', 'description', 'image', 'name',
         'thumbnail', 'family', 'expansion', 'compilation'],
         axis=1, inplace=True)

# %% [markdown]
# ## Counts derived from category aggregates

# %%
# Select categorical variable names
category_cols = df.select_dtypes(np.object).columns

# Iterate through each column and count unique values
for cat in category_cols:
    num_unique_values = len(set(','.join(df[cat].dropna()).replace(', ', ',').split(',')))
    print(f'Number of unique values of {cat}:\t\t{num_unique_values}')
# Out:
# Number of unique values of artist:		5416
# Number of unique values of category:		83
# Number of unique values of designer:		4476
# Number of unique values of mechanic:		51
# Number of unique values of publisher:		3045
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\2678682047.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   category_cols = df.select_dtypes(np.object).columns

# %%
# Count values in each categorical variable of each game
for cat in category_cols:
    df['num_' + cat] = [np.nan if x is np.nan 
                               else len(x) + 1 
                               for x in df[cat].str.findall(',')]

# Drop multi-level categorical variables
df.drop(['artist', 'designer', 'publisher'], axis=1, inplace=True)

# %%
# Drop rows that have missing values
df.dropna(inplace=True)

# Current data shape
df.shape
# Out:
# (5701, 16)

# %% [markdown]
# ## Categories derived from category aggregates
# Get a set of all unique values in each variable
# Create new columns based on these values
# Iterate through all rows and fill in dummy values for each new column
# Group these dummy variables if possible

# %%
# Create functions
def value_list(data: pd.DataFrame, col: str) -> list:
    """ Returns a list of unique values that included in a given column
    """
    # Join all values in the column then get a set of them
    value_set = set(','.join(df[col].dropna()).replace(', ', ',').split(','))

    # Make all string lower case for processing purpose
    repr_list = [x.lower() for x in list(value_set)]

    return repr_list

def create_dummies(data: pd.DataFrame, col: str, key_word: str) -> list:
    """ Creates dummies for a given category in a column
    """
    word_list = [1 if (x is not np.nan) and (key_word in str(x).lower())
                 else 0 if (x is not np.nan) and (key_word not in str(x).lower())
                 else np.nan for x in data[col]]
    return word_list


def dummy_loop(data: pd.DataFrame, col: str) -> pd.DataFrame:
    """ Returns a data frame of dummies 
    """
    # Iterate through columns
    for value in value_list(data, col):
        data[col + '_' + value] = create_dummies(data=data, col=col, key_word=value)
    
    # Drop the original columns
    data.drop(col, axis=1, inplace=True)
    return data

# %%
# Print out game categories
value_list(df, 'category')
# Out:
# ['prehistoric',
#  'age of reason',
#  'city building',
#  'card game',
#  'environmental',
#  'book',
#  'wargame',
#  'world war ii',
#  'puzzle',
#  'memory',
#  'exploration',
#  'travel',
#  'space exploration',
#  'aviation / flight',
#  'territory building',
#  'expansion for base-game',
#  'miniatures',
#  'real-time',
#  'science fiction',
#  'bluffing',
#  'american civil war',
#  'korean war',
#  'vietnam war',
#  'industry / manufacturing',
#  'zombies',
#  'american west',
#  'trivia',
#  'comic book / strip',
#  'party game',
#  'american revolutionary war',
#  'adventure',
#  'educational',
#  'post-napoleonic',
#  'farming',
#  'racing',
#  'american indian wars',
#  'electronic',
#  'ancient',
#  'political',
#  'movies / tv / radio theme',
#  'spies/secret agents',
#  'abstract strategy',
#  'pike and shot',
#  'civilization',
#  'math',
#  'maze',
#  'novel-based',
#  'medieval',
#  'murder/mystery',
#  'world war i',
#  'renaissance',
#  'modern warfare',
#  'word game',
#  'dice',
#  "children's game",
#  'arabian',
#  'civil war',
#  'deduction',
#  'medical',
#  'fighting',
#  'economic',
#  'mythology',
#  'pirates',
#  'action / dexterity',
#  'napoleonic',
#  'trains',
#  'transportation',
#  'number',
#  'animals',
#  'mafia',
#  'mature / adult',
#  'game system',
#  'video game theme',
#  'negotiation',
#  'music',
#  'sports',
#  'nautical',
#  'humor',
#  'fantasy',
#  'collectible components',
#  'print & play',
#  'religious',
#  'horror']

# %%
# Print out game mechanics
value_list(df, 'mechanic')
# Out:
# ['route/network building',
#  'action / movement programming',
#  'stock holding',
#  'line drawing',
#  'worker placement',
#  'voting',
#  'singing',
#  'player elimination',
#  'storytelling',
#  'paper-and-pencil',
#  'modular board',
#  'trick-taking',
#  'auction/bidding',
#  'memory',
#  'tile placement',
#  'crayon rail system',
#  'area movement',
#  'variable phase order',
#  'simultaneous action selection',
#  'card drafting',
#  'dice rolling',
#  'press your luck',
#  'chit-pull system',
#  'pattern building',
#  'area-impulse',
#  'pattern recognition',
#  'co-operative play',
#  'point to point movement',
#  'campaign / battle card driven',
#  'hex-and-counter',
#  'role playing',
#  'take that',
#  'partnerships',
#  'time track',
#  'area enclosure',
#  'variable player powers',
#  'trading',
#  'set collection',
#  'acting',
#  'deck / pool building',
#  'simulation',
#  'betting/wagering',
#  'rock-paper-scissors',
#  'grid movement',
#  'roll / spin and move',
#  'secret unit deployment',
#  'hand management',
#  'pick-up and deliver',
#  'action point allowance system',
#  'area control / area influence',
#  'commodity speculation']

# %%
# Apply functions to get dummies
df = dummy_loop(dummy_loop(df, 'category'), 'mechanic')

# Print out first 5 rows
df.head()
# Out:
#       max_players  max_playtime  min_age  min_players  min_playtime  \
# 6168            5            60       12            2            45
# 9652            5            20        8            1            20
# 5007            5           120       12            2            90
# 7409            6            30        8            2            30
# 3030            1           120       12            1           120
#
#       playing_time  year_published  average_rating  users_rated  num_artist  \
# 6168            60            2009         6.97479         2182         2.0
# 9652            20            2015         6.75647         3480         2.0
# 5007           120            2006         6.92051         1643         1.0
# 7409            30            2011         6.09375           80         1.0
# 3030           120            1974         6.05192          156         1.0
#
#       ...  mechanic_betting/wagering  mechanic_rock-paper-scissors  \
# 6168  ...                          0                             0
# 9652  ...                          0                             0
# 5007  ...                          0                             0
# 7409  ...                          0                             0
# 3030  ...                          0                             0
#
#       mechanic_grid movement  mechanic_roll / spin and move  \
# 6168                       0                              0
# 9652                       0                              0
# 5007                       0                              0
# 7409                       0                              0
# 3030                       0                              0
#
#       mechanic_secret unit deployment  mechanic_hand management  \
# 6168                                0                         1
# 9652                                0                         1
# 5007                                0                         0
# 7409                                0                         0
# 3030                                0                         0
#
#       mechanic_pick-up and deliver  mechanic_action point allowance system  \
# 6168                             0                                       0
# 9652                             0                                       0
# 5007                             0                                       0
# 7409                             0                                       0
# 3030                             0                                       0
#
#       mechanic_area control / area influence  mechanic_commodity speculation
# 6168                                       0                               0
# 9652                                       0                               0
# 5007                                       1                               1
# 7409                                       0                               0
# 3030                                       0                               0
#
# [5 rows x 148 columns]

# %%
# Current data shape
df.shape
# Out:
# (5701, 148)

# %%
# Check number of game categories
game_categories = df.filter(regex='^category_', axis=1)
game_categories.columns
# Out:
# Index(['category_prehistoric', 'category_age of reason',
#        'category_city building', 'category_card game',
#        'category_environmental', 'category_book', 'category_wargame',
#        'category_world war ii', 'category_puzzle', 'category_memory',
#        'category_exploration', 'category_travel', 'category_space exploration',
#        'category_aviation / flight', 'category_territory building',
#        'category_expansion for base-game', 'category_miniatures',
#        'category_real-time', 'category_science fiction', 'category_bluffing',
#        'category_american civil war', 'category_korean war',
#        'category_vietnam war', 'category_industry / manufacturing',
#        'category_zombies', 'category_american west', 'category_trivia',
#        'category_comic book / strip', 'category_party game',
#        'category_american revolutionary war', 'category_adventure',
#        'category_educational', 'category_post-napoleonic', 'category_farming',
#        'category_racing', 'category_american indian wars',
#        'category_electronic', 'category_ancient', 'category_political',
#        'category_movies / tv / radio theme', 'category_spies/secret agents',
#        'category_abstract strategy', 'category_pike and shot',
#        'category_civilization', 'category_math', 'category_maze',
#        'category_novel-based', 'category_medieval', 'category_murder/mystery',
#        'category_world war i', 'category_renaissance',
#        'category_modern warfare', 'category_word game', 'category_dice',
#        'category_children's game', 'category_arabian', 'category_civil war',
#        'category_deduction', 'category_medical', 'category_fighting',
#        'category_economic', 'category_mythology', 'category_pirates',
#        'category_action / dexterity', 'category_napoleonic', 'category_trains',
#        'category_transportation', 'category_number', 'category_animals',
#        'category_mafia', 'category_mature / adult', 'category_game system',
#        'category_video game theme', 'category_negotiation', 'category_music',
#        'category_sports', 'category_nautical', 'category_humor',
#        'category_fantasy', 'category_collectible components',
#        'category_print & play', 'category_religious', 'category_horror'],
#       dtype='object')

# %%
# Group categories based on BGG wiki
activity_categories = ['category_city building', 'category_civilization',
                       'category_educational', 'category_puzzle',
                       'category_racing', 'category_territory building',
                       'category_transportation']

component_categories = ['category_card game', 'category_collectible components',
                        'category_dice', 'category_electronic',
                        'category_miniatures']

nongame_categories = ['category_book', 'category_expansion for base-game',
                      'category_game system']

war_categories = list(df.filter(regex='war', axis=1).columns)
war_categories = war_categories + ['category_napoleonic', 'category_post-napoleonic',
                                   'category_pike and shot']

skills_categories = ['category_action / dexterity', 'category_bluffing',
                     'category_deduction', 'category_economic',
                     'category_math', 'category_number',
                     'category_memory', 'category_negotiation',
                     'category_real-time', 'category_spatial analysis',
                     'category_trivia', 'category_word game']

entertainment_categories = ['category_comic book / strip', 'category_movies / tv / radio theme',
                            'category_music', 'category_novel-based',
                            'category_video game theme']

nongroup_categories = ['category_party game', 'category_abstract strategy',
                       "category_children's game"]

# %%
# Create functions
def dummy_group(data: pd.DataFrame, category: list) -> list:
    """
    Returns a list of dummies derived from input category
    """
    for i in category:
        if i not in list(data.columns):
            category.remove(i)
    dummies = [1 if x >= 1 else 0 for x in data[category].sum(axis=1)]
    data.drop(category, axis=1, inplace=True)
    return dummies

def plot_bar(data: pd.DataFrame,
             prefix: str, figsize: tuple,
             title: str):
    category_df = (df
                   .filter(regex=prefix, axis=1)
                   .sum()
                   .to_frame('count')
                   .sort_values('count')
    )
    ax = category_df.plot.barh(legend=None, figsize=figsize, linewidth=0)
    ax.set_yticklabels(list(category_df.sort_values('count').index.str.replace(prefix,'')))
    ax.tick_params(labelsize=12)
    ax.set_title(title, fontsize=16)

# %%
# Apply dummy function to each category
df['category_activity'] = dummy_group(df, activity_categories)
df['category_component'] = dummy_group(df, component_categories)
df['category_nongame'] = dummy_group(df, nongame_categories)
df['category_war'] = dummy_group(df, war_categories)
df['category_skills'] = dummy_group(df, skills_categories)
df['category_entertainment'] = dummy_group(df, entertainment_categories)

# Select games only
df = df[df['category_nongame'] == 0]
df.drop('category_nongame', axis=1, inplace=True)

# %%
plot_bar(data=df,
         prefix='category_',
         figsize=(20,10),
         title='Number of Games by Category')

# %%
plot_bar(data=df,
         prefix='mechanic_',
         figsize=(20,10),
         title='Number of Games by Mechanic')

# %%
# Current data shape
df.shape
# Out:
# (5608, 109)

# %% [markdown]
# ## 3. Data Cleaning and Engineering: Numeric Data

# %%
# Select numeric data that are not binary
numeric_df = df.loc[:, ~df.isin([0,1]).all()]
numeric_df.shape
# Out:
# (5608, 14)

# %%
# Some statistics
numeric_df.describe()
# Out:
#        max_players  max_playtime      min_age  min_players  min_playtime  \
# count  5608.000000   5608.000000  5608.000000  5608.000000   5608.000000
# mean      5.010521    105.758559     9.955599     2.059379     91.313302
# std       7.543777    866.538797     3.301289     0.674542    848.267125
# min       0.000000      0.000000     0.000000     0.000000      0.000000
# 25%       4.000000     30.000000     8.000000     2.000000     30.000000
# 50%       4.000000     45.000000    10.000000     2.000000     45.000000
# 75%       6.000000     90.000000    12.000000     2.000000     90.000000
# max     362.000000  60000.000000    25.000000     9.000000  60000.000000
#
#        playing_time  year_published  average_rating   users_rated  \
# count   5608.000000     5608.000000     5608.000000   5608.000000
# mean     105.758559     2004.717725        6.546314   1166.660663
# std      866.538797       11.284651        0.775103   3548.581155
# min        0.000000     1951.000000        2.339400     50.000000
# 25%       30.000000     2001.000000        6.051200    100.000000
# 50%       45.000000     2009.000000        6.548855    237.000000
# 75%       90.000000     2013.000000        7.065962    755.250000
# max    60000.000000     2016.000000        9.003920  67655.000000
#
#         num_artist  num_category  num_designer  num_mechanic  num_publisher
# count  5608.000000   5608.000000   5608.000000   5608.000000    5608.000000
# mean      2.203994      2.651926      1.411733      2.600927       2.824893
# std       7.690679      1.300462      0.802652      1.501255       3.683774
# min       1.000000      1.000000      1.000000      1.000000       1.000000
# 25%       1.000000      2.000000      1.000000      1.000000       1.000000
# 50%       1.000000      2.000000      1.000000      2.000000       2.000000
# 75%       2.000000      3.000000      2.000000      3.000000       3.000000
# max     510.000000     14.000000     11.000000     12.000000      92.000000

# %%
# Select non zero rows only
df = df[(df.iloc[:,:6] > 0).all(axis=1)]

# %%
# Create game age variable from year published
df['game_age'] = 2019 - df['year_published']

# Drop unuseful columns
df.drop(['max_playtime', 'min_playtime', 'users_rated'], axis=1, inplace=True)

# %%
# Select data again
numeric_df = df.loc[:, ~df.isin([0,1]).all()]

# Current data shape
numeric_df.shape
# Out:
# (5240, 12)

# %%
# Check statistics again
numeric_df.describe()
# Out:
#        max_players      min_age  min_players  playing_time  year_published  \
# count  5240.000000  5240.000000  5240.000000   5240.000000     5240.000000
# mean      5.102290    10.471756     2.070611    101.502481     2004.554008
# std       7.753493     2.441990     0.666585    858.286053       11.397775
# min       1.000000     2.000000     1.000000      1.000000     1951.000000
# 25%       4.000000     8.000000     2.000000     30.000000     2000.000000
# 50%       4.000000    10.000000     2.000000     45.000000     2009.000000
# 75%       6.000000    12.000000     2.000000     90.000000     2013.000000
# max     362.000000    25.000000     9.000000  60000.000000     2016.000000
#
#        average_rating   num_artist  num_category  num_designer  num_mechanic  \
# count     5240.000000  5240.000000   5240.000000   5240.000000   5240.000000
# mean         6.525332     2.213550      2.663740      1.406870      2.624046
# std          0.765409     7.936809      1.316168      0.794444      1.512648
# min          2.339400     1.000000      1.000000      1.000000      1.000000
# 25%          6.036300     1.000000      2.000000      1.000000      1.000000
# 50%          6.525335     1.000000      2.000000      1.000000      2.000000
# 75%          7.032407     2.000000      3.000000      2.000000      3.000000
# max          9.003920   510.000000     14.000000     11.000000     12.000000
#
#        num_publisher     game_age
# count    5240.000000  5240.000000
# mean        2.909542    14.445992
# std         3.783639    11.397775
# min         1.000000     3.000000
# 25%         1.000000     6.000000
# 50%         2.000000    10.000000
# 75%         3.000000    19.000000
# max        92.000000    68.000000

# %%
# Create a functions to plot multiple bar charts
def hist_loop(data: pd.DataFrame,
              rows: int,
              cols: int,
              figsize: tuple):
    fig, axes = plt.subplots(rows,cols, figsize=figsize)
    for i, ax in enumerate(axes.flatten()):
        if i < len(data.columns):
            data[sorted(data.columns)[i]].plot.hist(bins=30, ax=ax)
            ax.set_title(f'{sorted(data.columns)[i]} distribution', fontsize=10)
            ax.tick_params(axis='x', labelsize=10)
            ax.tick_params(axis='y', labelsize=10)
            ax.get_yaxis().get_label().set_visible(False)
        else:
            fig.delaxes(ax=ax)
    fig.tight_layout()

# %%
hist_loop(data=numeric_df,
          rows=3,
          cols=4,
          figsize=(20,10))

# %%
# Create a function to check skewness
def skew_df(data: pd.DataFrame, skew_limit: float) -> pd.DataFrame:
    # Define a limit above which we will log transform
    skew_vals = data.skew()

    # Showing the skewed columns
    skew_cols = (skew_vals
                 .sort_values(ascending=False)
                 .to_frame('Skew')
                 .query('abs(Skew) > {}'.format(skew_limit))
    )
    return skew_cols

# %%
# Print out skewed columns
skew_cols = skew_df(numeric_df, 0.75)
skew_cols
# Out:
#                      Skew
# playing_time    65.229893
# num_artist      51.670589
# max_players     24.374155
# num_publisher    7.440751
# num_designer     3.308256
# min_players      2.043046
# game_age         1.437833
# num_mechanic     1.186188
# num_category     1.110221
# year_published  -1.437833

# %% [markdown]
# ## Log transformation for skewed variables

# %%
# Perform log transformation
for col in skew_cols.index.values:
    numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# Out:
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)
# C:\Users\698422\AppData\Local\Temp\ipykernel_16964\805296723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df['log_' + col] = numeric_df[col].apply(np.log1p)

# %%
# Check skewness on log transformed data
log_df = numeric_df.filter(regex='^log_', axis=1)
skew_log_cols = skew_df(log_df, 0.75)
skew_log_cols
# Out:
#                         Skew
# log_num_artist      2.491281
# log_num_designer    1.770511
# log_max_players     1.379365
# log_num_publisher   1.361302
# log_year_published -1.451667

# %%
# Plot log columns that have nearly normal distribution
log_df = log_df.drop(skew_log_cols.index, axis=1)
hist_loop(data=log_df.copy(),
          rows=3,
          cols=4,
          figsize=(20,10))

# %%
# Join these new columns to our dataset
df = df.join(log_df).drop([x.replace('log_', '') for x in log_df.columns], axis=1)

# %%
# Pairplot of numeric data
sns.pairplot(data=df, vars=['min_age', 'log_game_age', 'log_min_players', 'log_num_category',
                            'log_num_mechanic', 'log_playing_time', 'average_rating'],
             plot_kws=dict(alpha=.2, edgecolor='none'));

# %% [markdown]
# # Adding polynomial and interaction terms

# %%
from sklearn.preprocessing import PolynomialFeatures

# Instantiate and provide desired degree; 
# Note: degree=2 also includes intercept, degree 1 terms, and cross-terms
pf = PolynomialFeatures(degree=2)

# %%
# Select features
feature_cols = ['min_age', 'log_game_age', 'log_min_players', 'log_num_category',
                'log_num_mechanic', 'log_playing_time']
features = df[feature_cols]

# fit and transform
pf.fit(features)
feat_array = pf.transform(features)

# Create a data frame
feat_df = pd.DataFrame(feat_array,
                       index=df.index,
                       columns=pf.get_feature_names(input_features=features.columns))

# Drop the intercept
feat_df.drop('1', axis=1, inplace=True)

# Add in the target
feat_df.insert(0, 'average_rating', df['average_rating'])
# Out:
# C:\Users\698422\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Plot a heatmap of correlations
with sns.axes_style('white'):
    fig, axes = plt.subplots(figsize=(12,12))
    mask = np.triu(np.ones_like(feat_df.corr(), dtype=bool))
    sns.heatmap(feat_df.corr(),
                mask=mask,
                cmap='binary',
                cbar=False,
                annot=True,
                annot_kws={'size':10},
                fmt='.2f')
    plt.title('Polynomial Features and Their Correlations', fontsize=16)
    plt.tick_params(axis='x', labelsize=12)
    plt.tick_params(axis='y', labelsize=12)

# %%
# Join these new columns to our dataset
for col in feat_df.columns:
    if col in df.columns:
        feat_df.drop(col, axis=1, inplace=True)
df = df.join(feat_df)

# %% [markdown]
# ## Binning numeric data
# Binning numeric data that cannot be scaled by log transformation
# Dummy transformation

# %%
# Number of artists
pd.qcut(df['num_artist'], q=4, duplicates='drop')
# Out:
# 6168    (0.999, 2.0]
# 9652    (0.999, 2.0]
# 5007    (0.999, 2.0]
# 7409    (0.999, 2.0]
# 3030    (0.999, 2.0]
#             ...
# 7891    (0.999, 2.0]
# 9225    (2.0, 510.0]
# 4859    (0.999, 2.0]
# 9845    (0.999, 2.0]
# 2732    (0.999, 2.0]
# Name: num_artist, Length: 5240, dtype: category
# Categories (2, interval[float64, right]): [(0.999, 2.0] < (2.0, 510.0]]

# %%
df['group_artist'] = pd.qcut(df['num_artist'],
                             q=4,
                             duplicates='drop',
                             labels=['two_or_less', 'three_or_more'])
df.drop('num_artist', axis=1, inplace=True)
df = pd.get_dummies(df, columns=['group_artist'], drop_first=True)

# %%
# Number of designers
pd.qcut(df['num_designer'], q=4, duplicates='drop')
# Out:
# 6168    (0.999, 2.0]
# 9652    (0.999, 2.0]
# 5007    (0.999, 2.0]
# 7409    (0.999, 2.0]
# 3030    (0.999, 2.0]
#             ...
# 7891    (0.999, 2.0]
# 9225     (2.0, 11.0]
# 4859    (0.999, 2.0]
# 9845    (0.999, 2.0]
# 2732    (0.999, 2.0]
# Name: num_designer, Length: 5240, dtype: category
# Categories (2, interval[float64, right]): [(0.999, 2.0] < (2.0, 11.0]]

# %%
df['group_designer'] = pd.qcut(df['num_designer'],
                               q=4,
                               duplicates='drop',
                               labels=['two_or_less', 'three_or_more'])
df.drop('num_designer', axis=1, inplace=True)
df = pd.get_dummies(df, columns=['group_designer'], drop_first=True)

# %%
# Number of publishers
pd.qcut(df['num_publisher'], q=4, duplicates='drop')
# Out:
# 6168      (2.0, 3.0]
# 9652     (3.0, 92.0]
# 5007     (3.0, 92.0]
# 7409    (0.999, 2.0]
# 3030    (0.999, 2.0]
#             ...
# 7891    (0.999, 2.0]
# 9225    (0.999, 2.0]
# 4859      (2.0, 3.0]
# 9845     (3.0, 92.0]
# 2732    (0.999, 2.0]
# Name: num_publisher, Length: 5240, dtype: category
# Categories (3, interval[float64, right]): [(0.999, 2.0] < (2.0, 3.0] < (3.0, 92.0]]

# %%
pd.qcut(df['num_publisher'], q=3, duplicates='drop')
# Out:
# 6168    (0.999, 3.0]
# 9652     (3.0, 92.0]
# 5007     (3.0, 92.0]
# 7409    (0.999, 3.0]
# 3030    (0.999, 3.0]
#             ...
# 7891    (0.999, 3.0]
# 9225    (0.999, 3.0]
# 4859    (0.999, 3.0]
# 9845     (3.0, 92.0]
# 2732    (0.999, 3.0]
# Name: num_publisher, Length: 5240, dtype: category
# Categories (2, interval[float64, right]): [(0.999, 3.0] < (3.0, 92.0]]

# %%
df['group_publisher'] = pd.qcut(df['num_publisher'],
                                q=3,
                                duplicates='drop',
                                labels=['three_or_less', 'four_or_more'])
df.drop('num_publisher', axis=1, inplace=True)
df = pd.get_dummies(df, columns=['group_publisher'], drop_first=True)

# %%
# Number of maximum players
pd.qcut(df['max_players'], q=4, duplicates='drop')
# Out:
# 6168      (4.0, 6.0]
# 9652      (4.0, 6.0]
# 5007      (4.0, 6.0]
# 7409      (4.0, 6.0]
# 3030    (0.999, 4.0]
#             ...
# 7891      (4.0, 6.0]
# 9225      (4.0, 6.0]
# 4859      (4.0, 6.0]
# 9845      (4.0, 6.0]
# 2732    (6.0, 362.0]
# Name: max_players, Length: 5240, dtype: category
# Categories (3, interval[float64, right]): [(0.999, 4.0] < (4.0, 6.0] < (6.0, 362.0]]

# %%
df['group_max_players'] = pd.qcut(df['max_players'],
                                  q=4,
                                  duplicates='drop',
                                  labels=['four_or_less', 'five_or_six', 'seven_or_more'])
df.drop('max_players', axis=1, inplace=True)
df = pd.get_dummies(df, columns=['group_max_players'], drop_first=True)

# %%
# Year published
pd.qcut(df['year_published'], q=4, duplicates='drop')
# Out:
# 6168      (2000.0, 2009.0]
# 9652      (2013.0, 2016.0]
# 5007      (2000.0, 2009.0]
# 7409      (2009.0, 2013.0]
# 3030    (1950.999, 2000.0]
#                ...
# 7891      (2009.0, 2013.0]
# 9225      (2013.0, 2016.0]
# 4859      (2000.0, 2009.0]
# 9845      (2013.0, 2016.0]
# 2732    (1950.999, 2000.0]
# Name: year_published, Length: 5240, dtype: category
# Categories (4, interval[float64, right]): [(1950.999, 2000.0] < (2000.0, 2009.0] < (2009.0, 2013.0] < (2013.0, 2016.0]]

# %%
df['group_year_published'] = pd.qcut(df['year_published'],
                                     q=4,
                                     duplicates='drop',
                                     labels=['before_2001', 'between_2001_and_2009', 'between_2010_and_2013', 'between_2014_and_2016'])
df.drop('year_published', axis=1, inplace=True)
df = pd.get_dummies(df, columns=['group_year_published'], drop_first=True)

# %%
# Final dataset
df.head()
# Out:
#       min_age  average_rating  category_prehistoric  category_age of reason  \
# 6168       12         6.97479                     0                       0
# 9652        8         6.75647                     0                       0
# 5007       12         6.92051                     0                       0
# 7409        8         6.09375                     0                       0
# 3030       12         6.05192                     0                       0
#
#       category_environmental  category_exploration  category_travel  \
# 6168                       0                     0                0
# 9652                       0                     0                0
# 5007                       0                     0                0
# 7409                       0                     0                0
# 3030                       0                     0                0
#
#       category_space exploration  category_aviation / flight  \
# 6168                           0                           0
# 9652                           0                           0
# 5007                           0                           0
# 7409                           0                           0
# 3030                           0                           0
#
#       category_science fiction  ...  log_num_mechanic log_playing_time  \
# 6168                         0  ...                           5.698881
# 9652                         0  ...                           3.344750
# 5007                         0  ...                           8.592903
# 7409                         0  ...                           3.772621
# 3030                         0  ...                           5.268714
#
#       log_playing_time^2  group_artist_three_or_more  \
# 6168           16.899284                           0
# 9652            9.269117                           0
# 5007           22.999607                           0
# 7409           11.792268                           0
# 3030           22.999607                           0
#
#       group_designer_three_or_more  group_publisher_four_or_more  \
# 6168                             0                             0
# 9652                             0                             1
# 5007                             0                             1
# 7409                             0                             0
# 3030                             0                             0
#
#       group_max_players_five_or_six  group_max_players_seven_or_more  \
# 6168                              1                                0
# 9652                              1                                0
# 5007                              1                                0
# 7409                              1                                0
# 3030                              0                                0
#
#       group_year_published_between_2001_and_2009  \
# 6168                                           1
# 9652                                           0
# 5007                                           1
# 7409                                           0
# 3030                                           0
#
#       group_year_published_between_2010_and_2013  \
# 6168                                           0
# 9652                                           0
# 5007                                           0
# 7409                                           1
# 3030                                           0
#
#       group_year_published_between_2014_and_2016
# 6168                                           0
# 9652                                           1
# 5007                                           0
# 7409                                           0
# 3030                                           0
#
# [5 rows x 131 columns]

# %%
df.shape
# Out:
# (5240, 131)

# %%
from scipy.stats import ttest_ind, t

# %%
# Create a function to conduct Welch's test and plot distributions
def t_ind_test(s1: pd.Series,
               s2: pd.Series,
               equal_var=False) -> tuple:
    """
    Returns t-value and p-value
    """

    dfreedom = len(s1) + len(s2) - 2
    t_val, p_val = ttest_ind(s1, s2, equal_var=equal_var)
    return t_val, p_val

def test_loop(data: pd.DataFrame,
              prefix: str) -> pd.DataFrame:
    """
    Returns a table of t test result sorted by p-values 
    with colored bars (green for positive values and red for negative ones)
    """

    category_df = data.filter(regex=prefix, axis=1)
    category = sorted(list(category_df.columns))

    test_results = []
    for i in category:
        non_category_ratings = data[data[i] == 0]['average_rating']
        category_ratings = data[data[i] == 1]['average_rating']
        test_results.append((i.replace(prefix, ''),) + t_ind_test(category_ratings, non_category_ratings))

    test_results_df = (pd.DataFrame(test_results, columns=[prefix + 'name', 't-value', 'p-value'])
                       .sort_values('p-value')
                       .set_index(prefix + 'name')
    )
    test_results_df = test_results_df.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
    return test_results_df

# %%
test_loop(df, 'category_')
# Out:
# <style type="text/css">
# #T_3729b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row0_col1, #T_3729b_row1_col1, #T_3729b_row2_col1, #T_3729b_row3_col1, #T_3729b_row4_col1, #T_3729b_row5_col1, #T_3729b_row6_col1, #T_3729b_row7_col1, #T_3729b_row8_col1, #T_3729b_row9_col1, #T_3729b_row10_col1, #T_3729b_row11_col1, #T_3729b_row12_col1, #T_3729b_row13_col1, #T_3729b_row14_col1, #T_3729b_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.0%, transparent 0.0%);
# }
# #T_3729b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_3729b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 17.7%, #d65f5f 17.7%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.5%, #d65f5f 22.5%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.7%, #d65f5f 29.7%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.5%, #d65f5f 31.5%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 69.2%, transparent 69.2%);
# }
# #T_3729b_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 69.0%, transparent 69.0%);
# }
# #T_3729b_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 67.5%, transparent 67.5%);
# }
# #T_3729b_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 68.3%, transparent 68.3%);
# }
# #T_3729b_row10_col0, #T_3729b_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 66.7%, transparent 66.7%);
# }
# #T_3729b_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 67.0%, transparent 67.0%);
# }
# #T_3729b_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 65.6%, transparent 65.6%);
# }
# #T_3729b_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.1%, #d65f5f 41.1%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 65.2%, transparent 65.2%);
# }
# #T_3729b_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 64.6%, transparent 64.6%);
# }
# #T_3729b_row16_col1, #T_3729b_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.1%, transparent 0.1%);
# }
# #T_3729b_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 64.5%, transparent 64.5%);
# }
# #T_3729b_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 63.2%, transparent 63.2%);
# }
# #T_3729b_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.3%, transparent 0.3%);
# }
# #T_3729b_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 63.0%, transparent 63.0%);
# }
# #T_3729b_row19_col1, #T_3729b_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.4%, transparent 0.4%);
# }
# #T_3729b_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.2%, #d65f5f 43.2%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.4%, #d65f5f 45.4%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 2.2%, transparent 2.2%);
# }
# #T_3729b_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 60.9%, transparent 60.9%);
# }
# #T_3729b_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 2.4%, transparent 2.4%);
# }
# #T_3729b_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 60.5%, transparent 60.5%);
# }
# #T_3729b_row23_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 3.4%, transparent 3.4%);
# }
# #T_3729b_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 60.0%, transparent 60.0%);
# }
# #T_3729b_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 5.0%, transparent 5.0%);
# }
# #T_3729b_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.8%, #d65f5f 46.8%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 5.4%, transparent 5.4%);
# }
# #T_3729b_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 59.2%, transparent 59.2%);
# }
# #T_3729b_row26_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 8.5%, transparent 8.5%);
# }
# #T_3729b_row27_col0, #T_3729b_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 59.0%, transparent 59.0%);
# }
# #T_3729b_row27_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 9.0%, transparent 9.0%);
# }
# #T_3729b_row28_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 9.2%, transparent 9.2%);
# }
# #T_3729b_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.6%, #d65f5f 47.6%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row29_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 9.4%, transparent 9.4%);
# }
# #T_3729b_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 58.0%, transparent 58.0%);
# }
# #T_3729b_row30_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 16.0%, transparent 16.0%);
# }
# #T_3729b_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 57.6%, transparent 57.6%);
# }
# #T_3729b_row31_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 20.1%, transparent 20.1%);
# }
# #T_3729b_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 56.5%, transparent 56.5%);
# }
# #T_3729b_row32_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 33.2%, transparent 33.2%);
# }
# #T_3729b_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.6%, #d65f5f 50.6%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 43.8%, transparent 43.8%);
# }
# #T_3729b_row34_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.1%, #d65f5f 51.1%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row34_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 52.8%, transparent 52.8%);
# }
# #T_3729b_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 55.3%, transparent 55.3%);
# }
# #T_3729b_row35_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 55.1%, transparent 55.1%);
# }
# #T_3729b_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.7%, #d65f5f 51.7%, #d65f5f 53.3%, transparent 53.3%);
# }
# #T_3729b_row36_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 64.3%, transparent 64.3%);
# }
# #T_3729b_row37_col0, #T_3729b_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 54.7%, transparent 54.7%);
# }
# #T_3729b_row37_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 67.4%, transparent 67.4%);
# }
# #T_3729b_row38_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 6

# %%
test_loop(df, 'mechanic_')
# Out:
# <style type="text/css">
# #T_94cd3_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_94cd3_row0_col1, #T_94cd3_row1_col1, #T_94cd3_row2_col1, #T_94cd3_row3_col1, #T_94cd3_row4_col1, #T_94cd3_row5_col1, #T_94cd3_row6_col1, #T_94cd3_row7_col1, #T_94cd3_row8_col1, #T_94cd3_row9_col1, #T_94cd3_row10_col1, #T_94cd3_row11_col1, #T_94cd3_row12_col1, #T_94cd3_row13_col1, #T_94cd3_row14_col1, #T_94cd3_row15_col1, #T_94cd3_row16_col1, #T_94cd3_row17_col1, #T_94cd3_row18_col1, #T_94cd3_row19_col1, #T_94cd3_row20_col1, #T_94cd3_row21_col1, #T_94cd3_row22_col1, #T_94cd3_row23_col1, #T_94cd3_row24_col1, #T_94cd3_row25_col1, #T_94cd3_row26_col1, #T_94cd3_row27_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.0%, transparent 0.0%);
# }
# #T_94cd3_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 95.3%, transparent 95.3%);
# }
# #T_94cd3_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 92.8%, transparent 92.8%);
# }
# #T_94cd3_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 90.2%, transparent 90.2%);
# }
# #T_94cd3_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 90.0%, transparent 90.0%);
# }
# #T_94cd3_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 80.9%, transparent 80.9%);
# }
# #T_94cd3_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 81.2%, transparent 81.2%);
# }
# #T_94cd3_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 78.5%, transparent 78.5%);
# }
# #T_94cd3_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 75.6%, transparent 75.6%);
# }
# #T_94cd3_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 73.8%, transparent 73.8%);
# }
# #T_94cd3_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 74.4%, transparent 74.4%);
# }
# #T_94cd3_row12_col0, #T_94cd3_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 74.5%, transparent 74.5%);
# }
# #T_94cd3_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.9%, #d65f5f 15.9%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 71.3%, transparent 71.3%);
# }
# #T_94cd3_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 71.2%, transparent 71.2%);
# }
# #T_94cd3_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.8%, #d65f5f 21.8%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 63.7%, transparent 63.7%);
# }
# #T_94cd3_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 64.8%, transparent 64.8%);
# }
# #T_94cd3_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 69.2%, transparent 69.2%);
# }
# #T_94cd3_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.6%, #d65f5f 27.6%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 61.1%, transparent 61.1%);
# }
# #T_94cd3_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 61.5%, transparent 61.5%);
# }
# #T_94cd3_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.2%, #d65f5f 28.2%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 60.3%, transparent 60.3%);
# }
# #T_94cd3_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.0%, #d65f5f 29.0%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 59.3%, transparent 59.3%);
# }
# #T_94cd3_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 58.6%, transparent 58.6%);
# }
# #T_94cd3_row28_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.1%, transparent 0.1%);
# }
# #T_94cd3_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 57.0%, transparent 57.0%);
# }
# #T_94cd3_row29_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.3%, transparent 0.3%);
# }
# #T_94cd3_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 55.9%, transparent 55.9%);
# }
# #T_94cd3_row30_col1, #T_94cd3_row31_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.6%, transparent 0.6%);
# }
# #T_94cd3_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.3%, #d65f5f 30.3%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 55.8%, transparent 55.8%);
# }
# #T_94cd3_row32_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.7%, transparent 0.7%);
# }
# #T_94cd3_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.9%, #d65f5f 33.9%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 1.2%, transparent 1.2%);
# }
# #T_94cd3_row34_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.0%, #d65f5f 34.0%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row34_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 1.6%, transparent 1.6%);
# }
# #T_94cd3_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.4%, #d65f5f 34.4%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row35_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 2.1%, transparent 2.1%);
# }
# #T_94cd3_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 53.2%, transparent 53.2%);
# }
# #T_94cd3_row36_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 4.0%, transparent 4.0%);
# }
# #T_94cd3_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 52.8%, transparent 52.8%);
# }
# #T_94cd3_row37_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 6.0%, transparent 6.0%);
# }
# #T_94cd3_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 52.4%, transparent 52.4%);
# }
# #T_94cd3_row38_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 6.5%, transparent 6.5%);
# }
# #T_94cd3_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 52.3%, transparent 52.3%);
# }
# #T_94cd3_row39_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 7.5%, transparent 7.5%);
# }
# #T_94cd3_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, #5fba7d 44.5%, #5fba7d 51.3%, transparent 51.3%);
# }
# #T_94cd3_row40_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 11.6%, transparent 11.6%);
# }
# #T_94cd3_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.4%, #d65f5f 38.4%, #d65f5f 44.5%, transparent 44.5%);
# }
# #T_94cd3_row41_col1 {
#   width: 10em;
#   background: line

# %%
test_loop(df, 'group_')
# Out:
# <style type="text/css">
# #T_cf390_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.1%, #5fba7d 31.1%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_cf390_row0_col1, #T_cf390_row1_col1, #T_cf390_row2_col1, #T_cf390_row3_col1, #T_cf390_row4_col1, #T_cf390_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 0.0%, transparent 0.0%);
# }
# #T_cf390_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.1%, #5fba7d 31.1%, #5fba7d 64.0%, transparent 64.0%);
# }
# #T_cf390_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.1%, transparent 31.1%);
# }
# #T_cf390_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.3%, #d65f5f 2.3%, #d65f5f 31.1%, transparent 31.1%);
# }
# #T_cf390_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.1%, #5fba7d 31.1%, #5fba7d 52.1%, transparent 52.1%);
# }
# #T_cf390_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.1%, #5fba7d 31.1%, #5fba7d 47.5%, transparent 47.5%);
# }
# #T_cf390_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.1%, #5fba7d 31.1%, #5fba7d 40.1%, transparent 40.1%);
# }
# #T_cf390_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 44.1%, transparent 44.1%);
# }
# #T_cf390_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.0%, #d65f5f 23.0%, #d65f5f 31.1%, transparent 31.1%);
# }
# #T_cf390_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_cf390">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf390_level0_col0" class="col_heading level0 col0" >t-value</th>
#       <th id="T_cf390_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf390_level0_row0" class="row_heading level0 row0" >year_published_between_2014_and_2016</th>
#       <td id="T_cf390_row0_col0" class="data row0 col0" >21.686049</td>
#       <td id="T_cf390_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf390_level0_row1" class="row_heading level0 row1" >artist_three_or_more</th>
#       <td id="T_cf390_row1_col0" class="data row1 col0" >10.349241</td>
#       <td id="T_cf390_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf390_level0_row2" class="row_heading level0 row2" >year_published_between_2001_and_2009</th>
#       <td id="T_cf390_row2_col0" class="data row2 col0" >-9.785744</td>
#       <td id="T_cf390_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf390_level0_row3" class="row_heading level0 row3" >max_players_five_or_six</th>
#       <td id="T_cf390_row3_col0" class="data row3 col0" >-9.068495</td>
#       <td id="T_cf390_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf390_level0_row4" class="row_heading level0 row4" >publisher_four_or_more</th>
#       <td id="T_cf390_row4_col0" class="data row4 col0" >6.625750</td>
#       <td id="T_cf390_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf390_level0_row5" class="row_heading level0 row5" >year_published_between_2010_and_2013</th>
#       <td id="T_cf390_row5_col0" class="data row5 col0" >5.153826</td>
#       <td id="T_cf390_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cf390_level0_row6" class="row_heading level0 row6" >designer_three_or_more</th>
#       <td id="T_cf390_row6_col0" class="data row6 col0" >2.842000</td>
#       <td id="T_cf390_row6_col1" class="data row6 col1" >0.004688</td>
#     </tr>
#     <tr>
#       <th id="T_cf390_level0_row7" class="row_heading level0 row7" >max_players_seven_or_more</th>
#       <td id="T_cf390_row7_col0" class="data row7 col0" >-2.561497</td>
#       <td id="T_cf390_row7_col1" class="data row7 col1" >0.010632</td>
#     </tr>
#   </tbody>
# </table>
